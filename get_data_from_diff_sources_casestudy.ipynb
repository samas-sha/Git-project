# %% [markdown]
# <a href="https://colab.research.google.com/github/samas-sha/Git-project/blob/main/get_data_from_diff_sources_casestudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import sqlite3
import requests

# %% [markdown]
# #Step 1: Load SpaceX Launch Data from API

# %%
url1=' https://api.spacexdata.com/v4/launches'
responce= requests.get(url1)
data=responce.json()
#step 2 :convert to data frime
lounches_df=pd.DataFrame(data)
lounches_df
# Out:
#                                               fairings  \
# 0    {'reused': False, 'recovery_attempt': False, '...
# 1    {'reused': False, 'recovery_attempt': False, '...
# 2    {'reused': False, 'recovery_attempt': False, '...
# 3    {'reused': False, 'recovery_attempt': False, '...
# 4    {'reused': False, 'recovery_attempt': False, '...
# ..                                                 ...
# 200  {'reused': None, 'recovery_attempt': None, 're...
# 201  {'reused': None, 'recovery_attempt': None, 're...
# 202  {'reused': None, 'recovery_attempt': None, 're...
# 203  {'reused': None, 'recovery_attempt': None, 're...
# 204  {'reused': None, 'recovery_attempt': None, 're...
#
#                                                  links  \
# 0    {'patch': {'small': 'https://images2.imgbox.co...
# 1    {'patch': {'small': 'https://images2.imgbox.co...
# 2    {'patch': {'small': 'https://images2.imgbox.co...
# 3    {'patch': {'small': 'https://images2.imgbox.co...
# ...

# %%
lounches_df=lounches_df[['name','date_utc','success','details','rocket']]
lounches_df
# Out:
#                        name                  date_utc success  \
# 0                 FalconSat  2006-03-24T22:30:00.000Z   False
# 1                   DemoSat  2007-03-21T01:10:00.000Z   False
# 2               Trailblazer  2008-08-03T03:34:00.000Z   False
# 3                    RatSat  2008-09-28T23:15:00.000Z    True
# 4                  RazakSat  2009-07-13T03:35:00.000Z    True
# ..                      ...                       ...     ...
# 200           Transporter-6  2022-12-01T00:00:00.000Z    None
# 201                   TTL-1  2022-12-01T00:00:00.000Z    None
# 202  WorldView Legion 1 & 2  2022-12-01T00:00:00.000Z    None
# 203     Viasat-3 & Arcturus  2022-12-01T00:00:00.000Z    None
# 204          O3b mPower 3.4  2022-12-01T00:00:00.000Z    None
#
#                                                details  \
# 0     Engine failure at 33 seconds and loss of vehicle
# 1    Successful first stage burn and transition to ...
# ...

# %%
lounches_df['date_utc']=pd.to_datetime(lounches_df['date_utc'])
lounches_df['year']=lounches_df['date_utc'].dt.year
lounches_df
# Out:
# /tmp/ipython-input-3699229824.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lounches_df['date_utc']=pd.to_datetime(lounches_df['date_utc'])
# /tmp/ipython-input-3699229824.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lounches_df['year']=lounches_df['date_utc'].dt.year
#                        name                  date_utc success  \
# 0                 FalconSat 2006-03-24 22:30:00+00:00   False
# 1                   DemoSat 2007-03-21 01:10:00+00:00   False
# ...

# %% [markdown]
# #Step 2: Load Rocket Metadata

# %%
url2='https://api.spacexdata.com/v4/rockets'
request= requests.get(url2)
data=request.json()
rockets_df=pd.DataFrame(data)
rockets_df
# Out:
#                           height                        diameter  \
# 0  {'meters': 22.25, 'feet': 73}   {'meters': 1.68, 'feet': 5.5}
# 1  {'meters': 70, 'feet': 229.6}     {'meters': 3.7, 'feet': 12}
# 2  {'meters': 70, 'feet': 229.6}  {'meters': 12.2, 'feet': 39.9}
# 3   {'meters': 118, 'feet': 387}       {'meters': 9, 'feet': 30}
#
#                              mass  \
# 0      {'kg': 30146, 'lb': 66460}
# 1   {'kg': 549054, 'lb': 1207920}
# 2  {'kg': 1420788, 'lb': 3125735}
# 3  {'kg': 1335000, 'lb': 2943000}
#
#                                          first_stage  \
# 0  {'thrust_sea_level': {'kN': 420, 'lbf': 94000}...
# 1  {'thrust_sea_level': {'kN': 7607, 'lbf': 17100...
# 2  {'thrust_sea_level': {'kN': 22819, 'lbf': 5130...
# 3  {'thrust_sea_level': {'kN': 128000, 'lbf': 287...
#
#                                         second_stage  \
# 0  {'thrust': {'kN': 31, 'lbf': 7000}, 'payloads'...
# 1  {'thrust': {'kN': 934, 'lbf': 210000}, 'payloa...
# ...

# %%
rockets_df=rockets_df[['id','name','type','active','stages']]
rockets_df
# Out:
#                          id          name    type  active  stages
# 0  5e9d0d95eda69955f709d1eb      Falcon 1  rocket   False       2
# 1  5e9d0d95eda69973a809d1ec      Falcon 9  rocket    True       2
# 2  5e9d0d95eda69974db09d1ed  Falcon Heavy  rocket    True       2
# 3  5e9d0d96eda699382d09d1ee      Starship  rocket   False       2

# %% [markdown]
# #Step 3: Merge Launch and Rocket Data

# %%
merged_df = pd.merge(
    lounches_df,
    rockets_df,
    left_on='rocket',
    right_on='id',
    how='left'
)
merged_df
# Out:
#                      name_x                  date_utc success  \
# 0                 FalconSat 2006-03-24 22:30:00+00:00   False
# 1                   DemoSat 2007-03-21 01:10:00+00:00   False
# 2               Trailblazer 2008-08-03 03:34:00+00:00   False
# 3                    RatSat 2008-09-28 23:15:00+00:00    True
# 4                  RazakSat 2009-07-13 03:35:00+00:00    True
# ..                      ...                       ...     ...
# 200           Transporter-6 2022-12-01 00:00:00+00:00    None
# 201                   TTL-1 2022-12-01 00:00:00+00:00    None
# 202  WorldView Legion 1 & 2 2022-12-01 00:00:00+00:00    None
# 203     Viasat-3 & Arcturus 2022-12-01 00:00:00+00:00    None
# 204          O3b mPower 3.4 2022-12-01 00:00:00+00:00    None
#
#                                                details  \
# 0     Engine failure at 33 seconds and loss of vehicle
# 1    Successful first stage burn and transition to ...
# ...

# %% [markdown]
# #Step 4: Add Simulated Country Information

# %%
countries=['USA', 'Russia', 'India', 'China', 'France']
merged_df['county']=np.random.choice(countries,size=len(merged_df))
merged_df
# Out:
#                      name_x                  date_utc success  \
# 0                 FalconSat 2006-03-24 22:30:00+00:00   False
# 1                   DemoSat 2007-03-21 01:10:00+00:00   False
# 2               Trailblazer 2008-08-03 03:34:00+00:00   False
# 3                    RatSat 2008-09-28 23:15:00+00:00    True
# 4                  RazakSat 2009-07-13 03:35:00+00:00    True
# ..                      ...                       ...     ...
# 200           Transporter-6 2022-12-01 00:00:00+00:00    None
# 201                   TTL-1 2022-12-01 00:00:00+00:00    None
# 202  WorldView Legion 1 & 2 2022-12-01 00:00:00+00:00    None
# 203     Viasat-3 & Arcturus 2022-12-01 00:00:00+00:00    None
# 204          O3b mPower 3.4 2022-12-01 00:00:00+00:00    None
#
#                                                details  \
# 0     Engine failure at 33 seconds and loss of vehicle
# 1    Successful first stage burn and transition to ...
# ...

# %% [markdown]
# #Step 5: Store Merged Data in SQLite3

# %%
conn=sqlite3.connect('launche.db')

# %%
merged_df.to_sql('launche',conn,index=False)
# Out:
# 205

# %%
df_from_db=pd.read_sql('SELECT *FROM launche LIMIT 5',conn)
df_from_db
# Out:
#         name_x                   date_utc  success  \
# 0    FalconSat  2006-03-24 22:30:00+00:00        0
# 1      DemoSat  2007-03-21 01:10:00+00:00        0
# 2  Trailblazer  2008-08-03 03:34:00+00:00        0
# 3       RatSat  2008-09-28 23:15:00+00:00        1
# 4     RazakSat  2009-07-13 03:35:00+00:00        1
#
#                                              details  \
# 0   Engine failure at 33 seconds and loss of vehicle
# 1  Successful first stage burn and transition to ...
# 2  Residual stage 1 thrust led to collision betwe...
# 3  Ratsat was carried to orbit on the first succe...
# 4                                               None
#
#                      rocket  year                        id    name_y    type  \
# 0  5e9d0d95eda69955f709d1eb  2006  5e9d0d95eda69955f709d1eb  Falcon 1  rocket
# 1  5e9d0d95eda69955f709d1eb  2007  5e9d0d95eda69955f709d1eb  Falcon 1  rocket
# 2  5e9d0d95eda69955f709d1eb  2008  5e9d0d95eda69955f709d1eb  Falcon 1  rocket
# ...

# %% [markdown]
# #Step 6: Run SQL Queries on the Data to analyze

# %%
cursor=conn.cursor()

# %%
cursor.execute("""SELECT county,COUNT(*) AS launches_count
FROM launche
GROUP BY county
ORDER BY launches_count DESC""")

# %%
rows=cursor.fetchall()
for row in rows:
  print(row)
# Out:
# ('Russia', 53)
# ('China', 42)
# ('France', 40)
# ('USA', 35)
# ('India', 35)

# %%
cursor.execute("""SELECT year,COUNT(*) AS launches_count
FROM launche
GROUP BY year
ORDER BY launches_count DESC limit 1""")

# %%
rows=cursor.fetchall()
for row in rows:
  print(row)
# Out:
# (2022, 62)

# %%
cursor.execute("""SELECT name_x,COUNT(*) AS launches_count
FROM launche
GROUP BY name_x
ORDER BY launches_count DESC limit 5""")

# %%
rows=cursor.fetchall()
for row in rows:
  print(row)
# Out:
# ('ispace Mission 1 & Rashid', 1)
# ('ZUMA', 1)
# ('WorldView Legion 1 & 2', 1)
# ('Viasat-3 & Arcturus', 1)
# ('USSF-44', 1)

# %%
cursor.execute("""SELECT name_y,COUNT(*) AS launches_count
FROM launche
GROUP BY name_y
ORDER BY launches_count DESC limit 5""")

# %%
rows=cursor.fetchall()
for row in rows:
  print(row)
# Out:
# ('Falcon 9', 195)
# ('Falcon Heavy', 5)
# ('Falcon 1', 5)

# %% [markdown]
# #
